# %% [markdown]
# # Homework 08
# This homework is based on the clustering lectures. Check the lecture notes and TA notes - they should help!

# %% [markdown]
# ## Question 1
# This question will walk you through creating your own `kmeans` function.

# %% [markdown]
# #### a) What are the steps of `kmeans`?
# **Hint**: There are 4 steps/builder functions that you'll need.

# %% [markdown]
# The first step is to randomly assign points to a cluster. Then, you calculate the mean (centroid) of all points is assigned to that cluster. Next, the points are reassigned to the cluster whose centroid is closest. This is repeated until the cluster assignments stop changing.

# %% [markdown]
# #### b) Create the builder function for step 1.

# %%
random_label <- function(points_n, clusters_n) {
  sample(rep(1:clusters_n, length.out=points_n))
}

# %% [markdown]
# #### c) Create the builder function for step 2.

# %%
assign_cluster <- function(df, means) {
  labels <- c()
  for (i in 1:nrow(df)) {
    point <- df[i, ]
    dists <- apply(means[, -1, drop=FALSE], 1, function(center){
      sum((as.numeric(point) - center)^2)
    })
    labels <- c(labels, means$cluster[which.min(dists)])
  }
  labels
}

# %% [markdown]
# #### d) Create the builder function for step 3.
# *Hint*: There are two ways to do this part - one is significantly more efficient than the other. You can do either.

# %%
get_cluster_means <- function(df, labels) {
  df |>
    mutate(cluster = labels) |>
    group_by(cluster)|>
    summarize(across(everything(), mean), .groups="drop") |>
    arrange(cluster)
}

# %% [markdown]
# #### e) Create the builder function for step 4.

# %%
kmeans_end <- function(old_means, new_means, eps=1e-6) {
  om <- as.matrix(old_means[, -1, drop=FALSE])
  nm <- as.matrix(new_means[, -1, drop=FALSE])
  diff <- sqrt(rowSums((om-nm)^2))
  mean(diff) < eps
}

# %% [markdown]
# #### f) Combine them all into your own `kmeans` function.

# %%
my_kmeans <- function(df, clusters_n, eps=1e-6, max_i = 100) {
  labels <- random_label(nrow(df), clusters_n)
  old_means <- get_cluster_means(df, labels)
  done <- FALSE
  i <- 0

  while(!done && i<max_i) {
    i <- i+1
    labels <- assign_cluster(df, old_means)
    new_means <- get_cluster_means(df, labels)
    if (kmeans_end(old_means,new_means,eps)){
      done <- TRUE
    }
    old_means <- new_means
  }
  list(labels = labels, means = new_means, iter=i)
}

# %% [markdown]
# ## Question 2
# This is when we'll test your `kmeans` function.
# #### a) Read in the `voltages_df.csv` data set.

# %%
library(tidyverse)
voltages_df <- read_csv("voltages_df.csv")
# Out:
# Rows: 900 Columns: 250
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# dbl (250): 0, 1.00401606425703, 2.00803212851406, 3.01204819277108, 4.016064...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %% [markdown]
# #### b) Call your `kmeans` function with 3 clusters. Print the results with `results$labels` and `results$means`.

# %%
results <- my_kmeans(voltages_df,3)
print(results$labels)
print(results$means)
# Out:
#   [1] 2 3 3 3 3 3 1 1 3 2 2 2 1 2 3 2 2 2 2 2 3 3 3 3 3 2 2 2 1 1 1 1 3 1 1 3 3
#  [38] 2 1 3 2 2 2 1 3 1 1 3 1 1 3 1 2 2 1 2 3 2 1 3 2 2 3 2 1 1 3 1 2 1 2 3 1 1
#  [75] 3 3 2 1 1 1 1 1 3 1 1 3 3 3 2 1 1 1 3 1 3 3 1 3 3 1 1 1 3 1 2 2 1 2 2 3 2
# [112] 2 3 1 2 1 2 2 3 3 3 3 2 2 1 3 3 1 2 1 3 2 3 1 2 3 3 3 2 1 2 3 3 1 2 2 3 2
# [149] 2 1 2 1 3 3 1 2 1 1 3 2 1 1 2 3 2 1 3 2 3 2 2 1 3 2 1 1 3 1 2 3 1 3 1 2 1
# [186] 3 3 2 3 2 2 3 2 2 1 1 2 3 2 2 1 2 1 1 3 2 3 1 3 2 3 1 2 1 1 3 1 1 3 3 3 3
# [223] 3 3 3 1 1 1 1 2 3 2 1 3 3 1 1 2 2 1 1 2 1 1 3 1 2 1 1 3 1 3 2 1 3 1 1 2 2
# [260] 2 3 3 1 2 3 3 3 1 1 1 2 3 3 3 1 2 1 1 3 3 1 2 1 2 2 3 1 3 3 1 1 2 1 1 2 3
# [297] 2 1 1 3 3 1 2 2 2 1 2 3 3 3 2 2 2 2 2 2 3 2 3 2 2 1 3 1 2 2 2 2 3 2 3 2 1
# [334] 2 3 3 1 1 2 3 1 3 1 1 2 1 3 1 2 2 1 3 3 3 2 1 3 2 1 1 3 3 3 3 2 1 2 3 2 2
# [371] 2 2 2 3 3 1 1 2 2 2 2 1 1 2 2 1 1 3 3 1 2 3 3 3 3 1 3 3 1 2 2 2 2 3 3 2 2
# [408] 1 1 1 3 1 1 2 3 3 3 1 3 3 3 2 2 3 2 1 3 3 3 3 1 1 3 1 2 3 2 2 2 1 1 1 1 2
# [445] 3 2 2 2 1 3 2 2 2 3 3 2 3 3 2 1 3 3 2 1 3 3 3 2 1 1 2 1 2 3 3 1 2 1 2 3 3
# [482] 1 2 1 1 1 3 1 1 1 1 1 3 2 2 1 1 2 3 3 3 2 2 2 3 3 1 1 2 1 2 3 3 1 1 2 1 1
# [519] 3 2 2 2 3 1 2 3 1 1 2 3 1 1 1 1 2 2 3 2 2 3 3 3 3 1 2 2 1 2 2 2 3 3 2 3 1
# [556] 1 3 1 1 1 3 1 1 3 1 1 3 1 1 2 1 3 1 3 1 3 3 3 2 1 1 1 1 2 3 1 1 1 3 1 1 3
# [593] 3 3 1 2 3 3 2 3 1 3 3 1 2 2 1 1 1 3 1 2 3 2 1 3 2 3 3 2 1 3 2 1 1 2 3 2 1
# [630] 3 2 1 2 3 3 2 3 2 2 2 2 2 3 3 2 1 2 1 1 2 1 3 1 2 1 2 2 2 3 2 2 3 3 2 2 3
# [667] 2 3 1 1 3 2 3 2 2 1 3 3 2 1 2 3 1 1 2 2 3 2 3 3 1 1 1 1 3 3 3 2 1 3 2 1 1
# [704] 2 2 1 3 1 1 2 3 2 1 3 2 3 3 2 3 3 2 2 3 3 2 3 1 2 2 2 2 2 3 3 2 2 3 3 2 3
# [741] 2 3 1 2 2 2 3 2 1 3 3 2 2 1 2 2 1 2 1 1 2 2 3 1 2 3 1 3 3 2 1 3 1 2 3 2 2
# [778] 1 2 1 3 2 2 3 1 3 2 3 2 1 2 2 3 3 3 2 3 2 1 3 3 3 3 2 2 1 3 2 2 2 2 1 1 2
# [815] 1 2 3 2 3 1 3 3 3 3 3 1 1 3 1 1 1 1 1 1 3 2 2 3 1 1 2 3 1 1 1 1 2 2 3 1 3
# [852] 2 1 1 1 1 2 2 1 1 1 1 1 2 3 1 3 2 3 3 1 2 1 1 2 2 3 2 2 2 1 3 1 3 3 2 2 1
# [889] 1 3 2 1 1 3 3 3 3 2 1 1
# # A tibble: 3 × 251
#   cluster   `0` `1.00401606425703` `2.00803212851406` `3.01204819277108`
#     <int> <dbl>              <dbl>              <dbl>              <dbl>
# 1       1 -1.03              1.31               1.16               0.979
# 2       2 -1.03              0.938              0.762              0.363
# 3       3 -1.03              1.24               1.09               0.900
# # ℹ 246 more variables: `4.01606425702811` <dbl>, `5.02008032128514` <dbl>,
# #   `6.02409638554217` <dbl>, `7.0281124497992` <dbl>,
# #   `8.03212851405623` <dbl>, `9.03614457831325` <dbl>,
# #   `10.0401606425703` <dbl>, `11.0441767068273` <dbl>,
# #   `12.0481927710843` <dbl>, `13.0522088353414` <dbl>,
# #   `14.0562248995984` <dbl>, `15.0602409638554` <dbl>,
# #   `16.0642570281125` <dbl>, `17.0682730923695` <dbl>, …

# %% [markdown]
# #### c) Call R's `kmeans` function with 3 clusters. Print the results with `results$labels` and `results$cluster`.
# *Hint*: Use the `as.matrix()` function to make the `voltages_df` data frame a matrix before calling `kmeans()`.

# %%
results_r <- kmeans(as.matrix(voltages_df), centers = 3)
print(results_r$cluster)
print(results_r$centers)
# Out:
#   [1] 3 1 1 1 1 1 2 2 1 3 3 3 2 3 1 3 3 3 3 3 1 1 1 1 1 3 3 3 2 2 2 2 1 2 2 1 1
#  [38] 3 2 1 3 3 3 2 1 2 2 1 2 2 1 2 3 3 2 3 1 3 2 1 3 3 1 3 2 2 1 2 3 2 3 1 2 2
#  [75] 1 1 3 2 2 2 2 2 1 2 2 1 1 1 3 2 2 2 1 2 1 1 2 1 1 2 2 2 1 2 3 3 2 3 3 1 3
# [112] 3 1 2 3 2 3 3 1 1 1 1 3 3 2 1 1 2 3 2 1 3 1 2 3 1 1 1 3 2 3 1 1 2 3 3 1 3
# [149] 3 2 3 2 1 1 2 3 2 2 1 3 2 2 3 1 3 2 1 3 1 3 3 2 1 3 2 2 1 2 3 1 2 1 2 3 2
# [186] 1 1 3 1 3 3 1 3 3 2 2 3 1 3 3 2 3 2 2 1 3 1 2 1 3 1 2 3 2 2 1 2 2 1 1 1 1
# [223] 1 1 1 2 2 2 2 3 1 3 2 1 1 2 2 3 3 2 2 3 2 2 1 2 3 2 2 1 2 1 3 2 1 2 2 3 3
# [260] 3 1 1 2 3 1 1 1 2 2 2 3 1 1 1 2 3 2 2 1 1 2 3 2 3 3 1 2 1 1 2 2 3 2 2 3 1
# [297] 3 2 2 1 1 2 3 3 3 2 3 1 1 1 3 3 3 3 3 3 1 3 1 3 3 2 1 2 3 3 3 3 1 3 1 3 2
# [334] 3 1 1 2 2 3 1 2 1 2 2 3 2 1 2 3 3 2 1 1 1 3 2 1 3 2 2 1 1 1 1 3 2 3 1 3 3
# [371] 3 3 3 1 1 2 2 3 3 3 3 2 2 3 3 2 2 1 1 2 3 1 1 1 1 2 1 1 2 3 3 3 3 1 1 3 3
# [408] 2 2 2 1 2 2 3 1 1 1 2 1 1 1 3 3 1 3 2 1 1 1 1 2 2 1 2 3 1 3 3 3 2 2 2 2 3
# [445] 1 3 3 3 2 1 3 3 3 1 1 3 1 1 3 2 1 1 3 2 1 1 1 3 2 2 3 2 3 1 1 2 3 2 3 1 1
# [482] 2 3 2 2 2 1 2 2 2 2 2 1 3 3 2 2 3 1 1 1 3 3 3 1 1 2 2 3 2 3 1 1 2 2 3 2 2
# [519] 1 3 3 3 1 2 3 1 2 2 3 1 2 2 2 2 3 3 1 3 3 1 1 1 1 2 3 3 2 3 3 3 1 1 3 1 2
# [556] 2 1 2 2 2 1 2 2 1 2 2 1 2 2 3 2 1 2 1 2 1 1 1 3 2 2 2 2 3 1 2 2 2 1 2 2 1
# [593] 1 1 2 3 1 1 3 1 2 1 1 2 3 3 2 2 2 1 2 3 1 3 2 1 3 1 1 3 2 1 3 2 2 3 1 3 2
# [630] 1 3 2 3 1 1 3 1 3 3 3 3 3 1 1 3 2 3 2 2 3 2 1 2 3 2 3 3 3 1 3 3 1 1 3 3 1
# [667] 3 1 2 2 1 3 1 3 3 2 1 1 3 2 3 1 2 2 3 3 1 3 1 1 2 2 2 2 1 1 1 3 2 1 3 2 2
# [704] 3 3 2 1 2 2 3 1 3 2 1 3 1 1 3 1 1 3 3 1 1 3 1 2 3 3 3 3 3 1 1 3 3 1 1 3 1
# [741] 3 1 2 3 3 3 1 3 2 1 1 3 3 2 3 3 2 3 2 2 3 3 1 2 3 1 2 1 1 3 2 1 2 3 1 3 3
# [778] 2 3 2 1 3 3 1 2 1 3 1 3 2 3 3 1 1 1 3 1 3 2 1 1 1 1 3 3 2 1 3 3 3 3 2 2 3
# [815] 2 3 1 3 1 2 1 1 1 1 1 2 2 1 2 2 2 2 2 2 1 3 3 1 2 2 3 1 2 2 2 2 3 3 1 2 1
# [852] 3 2 2 2 2 3 3 2 2 2 2 2 3 1 2 1 3 1 1 2 3 2 2 3 3 1 3 3 3 2 1 2 1 1 3 3 2
# [889] 2 1 3 2 2 1 1 1 1 3 2 2
#           0 1.00401606425703 2.00803212851406 3.01204819277108 4.01606425702811
# 1 -1.031463        1.2439759        1.0924697        0.9004440        0.3011754
# 2 -1.031463        1.3093239        1.1616772        0.9787498        0.6481497
# 3 -1.031463        0.9381238        0.7619864        0.3631543       -1.1179412
#   5.02008032128514 6.02409638554217 7.0281124497992 8.03212851405623
# 1        -1.159714       -1.1098127      -1.0685484       -1.0338649
# 2        -1.168610       -1.1196122      -1.0590962       -0.9943176
# 3        -1.051145       -0.9766807      -0.8694758       -0.6892375
#   9.03614457831325 10.0401606425703 11.0441767068273 12.0481927710843
# 1       -1.0022396       -0.9699741       -0.9343697       -0.8943605
# 2       -0.9237437       -0.8457536       -0.7572129       -0.6201221
# 3       -0.5661321       -0.2497152        0.6027358        0.6960355
#   13.0522088353414 14.0562248995984 15.0602409638554 16.0642570281125
# 1       -0.8507035       -0.8060072       -0.7647395       -0.7329406
# 2       -0.1849969        0.5921819        0.6827391        0.1509102
# 3        0.3917273       -0.9473202       -1.0883844       -1.0443762
#   17.0682730923695 18.0722891566265 19.0763052208835 20.0803212851406
# 1       -0.7162848       -0.7155110       -0.7229214       -0.7325077
# 2       -0.8453464       -1.0161305       -0.9911278       -0.9534526
# 3       -1.0057512       -0.9698542       -0.9344880       -0.8979255
#   21.0843373493976 22.0883534136546 23.0923694779116 24.0963855421687
# 1       -0.7420098       -0.7501943       -0.7564416       -0.7604952
# 2       -0.9278338       -0.9128185       -0.9036753       -0.8938970
# 3       -0.8583498       -0.8130091       -0.7569233       -0.6702728
#   25.1004016064257 26.1044176706827 27.1084337349398 28.1124497991968
# 1       -0.7624458       -0.7628025       -0.7623710       -0.7617723
# 2       -0.8772257       -0.8486353       -0.8039844       -0.7376698
# 3       -0.3675540        0.5506211        0.9011507        0.6795731
#   29.1164658634538 30.1204819277108 31.1244979919679 32.1285140562249
# 1       -0.7607406      -0.75765775       -0.7496843       -0.7333197
# 2       -0.6036243       0.06859829        0.8128548        0.8645315
# 3       -0.3524483      -1.04171502       -1.0459201       -0.9892448
#   33.1325301204819 34.136546184739 35.140562248996 36.144578313253
# 1       -0.7046809      -0.6531653      -0.4914149     -0.01286284
# 2        0.3007530      -0.8509538      -1.0593609     -0.99733097
# 3       -0.9443322      -0.9096994      -0.8815063     -0.85520281
#   37.1485943775101 38.1526104417671 39.1566265060241 40.1606425702811
# 1        0.4111138        0.4708061      -0.08318854       -0.6569424
# 2       -0.9264019       -0.8615397      -0.80559654       -0.7625137
# 3       -0.8276580       -0.7988569      -0.77307667       -0.7587053
#   41.1646586345382 42.1686746987952 43.1726907630522 44.1767068273092
# 1       -0.9102454       -0.8994279       -0.7365828       -0.6090580
# 2       -0.7331843       -0.7265177       -0.7332993       -0.7452244
# 3       -0.7632138       -0.7847630       -0.8145071       -0.8440694
#   45.1807228915663 46.1847389558233 47.1887550200803 48.1927710843374
# 1       -0.4429131       -0.1988909        0.3264548        0.4558868
# 2       -0.7541076       -0.7630892       -0.7738323       -0.7890510
# 3       -0.8675246       -0.8809781       -0.8820439       -0.8695599
#   49.1967871485944 50.2008032128514 51.2048192771084 52.2088353413655
# 1        0.1505446       -0.5861572       -0.9231358       -1.0150048
# 2       -0.8105414       -0.8376561       -0.8674783       -0.8961943
# 3       -0.8435323       -0.8053154       -0.7581727       -0.7076670
#   53.2128514056225 54.2168674698795 55.2208835341365 56.2248995983936
# 1       -0.9812155       -0.9519898       -0.9255601       -0.8963167
# 2       -0.9203792       -0.9376461       -0.9467293       -0.9471597
# 3       -0.6518253       -0.6418336       -0.6683513       -0.7186505
#   57.2289156626506 58.2329317269076 59.2369477911647 60.2409638554217
# 1       -0.8594356       -0.8113235       -0.7465117       -0.6458075
# 2       -0.9387284       -0.9209543       -0.8927547       -0.8524303
# 3       -0.7510866       -0.7687534       -0.7789676       -0.7875447
#   61.2449799196787 62.2489959839357 63.2530120481928 64.2570281124498
# 1       -0.4698973       -0.2004182       -0.2769707      -0.58780082
# 2       -0.7977063       -0.7247251       -0.5933942      -0.02666874
# 3       -0.7974017       -0.8105436       -0.8270493      -0.84511879
#   65.2610441767068 66.2650602409639 67.2690763052209 68.2730923694779
# 1       -0.8843039       -0.9061849       -0.9151609       -0.9136858
# 2        0.4729405        0.4144252       -0.4315513       -1.0008879
# 3       -0.8619288       -0.8745335       -0.8804324       -0.8778206
#   69.2771084337349 70.281124497992 71.285140562249 72.289156626506
# 1       -0.8979656      -0.8643462      -0.8085071      -0.7200554
# 2       -1.0090643      -0.9817530      -0.9556980      -0.9281157
# 3       -0.8656564      -0.8436347      -0.8120791      -0.7717843
#   73.2931726907631 74.2971887550201 75.3012048192771 76.3052208835341
# 1       -0.3865882        0.5166925        0.8451196        0.6232395
# 2       -0.8958956       -0.8562554       -0.8077624       -0.7520997
# 3       -0.7224965       -0.6589461       -0.5355189       -0.4204487
#   77.3092369477912 78.3132530120482 79.3172690763052 80.3212851405623
# 1       -0.5961787       -1.0623477       -1.0724163       -1.0356110
# 2       -0.6983205       -0.6636690       -0.6749499       -0.7301447
# 3       -0.4492026       -0.6247444       -0.7674160       -0.8087844
#   81.3253012048193 82.3293172690763 83.3333333333333 84.3373493975904
# 1       -0.9954282       -0.9528213       -0.9064278       -0.8582115
# 2       -0.8166818       -0.8587393       -0.8799611       -0.8807739
# 3       -0.8300087       -0.8472407       -0.8581972       -0.8615963
#   85.3413654618474 86.3453815261044 87.3493975903614 88.3534136546185
# 1       -0.8140585       -0.7829844       -0.7718335      -0.77702656
# 2       -0.8565428       -0.8006910       -0.6918535       0.01211907
# 3       -0.8575195       -0.8475783       -0.8346705      -0.82209589
#   89.3574297188755 90.3614457831325 91.3654618473896 92.3694779116466
# 1       -0.7871946       -0.7928432       -0.7890063       -0.7742481
# 2        1.0445785        0.9417920        0.7389057       -0.7150875
# 3       -0.8120214       -0.8040541       -0.7951620       -0.7810723
#   93.3734939759036 94.3775100401606 95.3815261044177 96.3855421686747
# 1       -0.7499086       -0.7199963       -0.6912508       -0.6620338
# 2       -1.1089291       -1.0556228       -1.0180026       -0.9953800
# 3       -0.7579365       -0.7232338       -0.6641211       -0.5714035
#   97.3895582329317 98.3935742971888 99.3975903614458 100.401606425703
# 1       -0.6573335       -0.6680024        -0.693500       -0.6899649
# 2       -0.9809828       -0.9669849        -0.947114       -0.9178894
# 3       -0.4183154       -0.3719077        -0.503291       -0.7008495
#   101.40562248996 102.409638554217 103.413654618474 104.417670682731
# 1      -0.6756290       -0.6511730       -0.5867081       -0.4940197
# 2      -0.8791665       -0.8349946       -0.7952200       -0.7756150
# 3      -0.7746358       -0.7625038       -0.7285317       -0.6571094
#   105.421686746988 106.425702811245 107.429718875502 108.433734939759
# 1       -0.3959773       -0.4019194       -0.4836075       -0.6031085
# 2       -0.7869612       -0.8196682       -0.8572411       -0.8888497
# 3       -0.4043544        0.1265605        0.3638254        0.1859342
#   109.437751004016 110.441767068273 111.44578313253 112.449799196787
# 1       -0.6803393       -0.7009213      -0.7220232       -0.7586346
# 2       -0.9084385       -0.9129518      -0.9016455       -0.8760331
# 3       -0.4285780       -0.7651785      -0.9118234       -0.9492127
#   113.453815261044 114.457831325301 115.461847389558 116.465863453815
# 1       -0.7931128       -0.8129309       -0.8240816       -0.8223207
# 2       -0.8402975       -0.8021679       -0.7735978       -0.7672098
# 3       -0.9263633       -0.9037028       -0.8843812       -0.8642445
#   117.469879518072 118.473895582329 119.477911646586 120.481927710843
# 1       -0.8048594       -0.7706219       -0.7204532       -0.6522148
# 2       -0.7838746       -0.8118719       -0.8402008       -0.8622569
# 3       -0.8387891       -0.8041192       -0.7572864       -0.6936271
#   121.4859437751 122.489959839357 123.493975903614 124.497991967871
# 1     -0.4767159       -0.4081569       -0.5063971      -0.76474266
# 2     -0.8743578       -0.8745548       -0.8621162      -0.83738609
# 3     -0.5608583       -0.1942616        0.1086731       0.02132084
#   125.502008032129 126.506024096386 127.510040160643 128.5140562249
# 1       -0.8404665       -0.8547187       -0.8574783     -0.8470736
# 2       -0.8019045       -0.7588503       -0.7139745     -0.6607540
# 3       -0.5326843       -0.8758425       -0.9333571     -0.9340874
#   129.518072289157 130.522088353414 131.526104417671 132.530120481928
# 1       -0.8237992       -0.7907006       -0.7549813       -0.7297735
# 2       -0.6276292       -0.6446482       -0.7145974       -0.7611321
# 3       -0.9361184       -0.9390643       -0.9391331       -0.9326577
#   133.534136546185 134.538152610442 135.542168674699 136.546184738956
# 1       -0.7298815       -0.7529255       -0.7848950       -0.8165587
# 2       -0.7857777       -0.8012031       -0.8125440       -0.8201603
# 3       -0.9172195       -0.8925731       -0.8614265       -0.8300492
#   137.550200803213 138.55421686747 139.558232931727 140.562248995984
# 1       -0.8425382      -0.8596402       -0.8659917       -0.8606862
# 2       -0.8247583      -0.8271200       -0.8278544       -0.8272444
# 3       -0.8077430      -0.8024823       -0.8136626       -0.8322854
#   141.566265060241 142.570281124498 143.574297188755 144.578313253012
# 1       -0.8437425       -0.8162919       -0.7810048       -0.7418578
# 2       -0.8252812       -0.8218972       -0.8172887       -0.8121326
# 3       -0.8483442       -0.8544481       -0.8456450       -0.8186060
#   145.582329317269 146.586345381526 147.590361445783 148.59437751004
# 1       -0.7067689       -0.6901358       -0.7059361     -0.73487063
# 2       -0.8075060       -0.8044394       -0.8032921     -0.80337598
# 3       -0.7708364       -0.6983153       -0.4995888      0.06111762
#   149.598393574297 150.602409638554 151.606425702811 152.610441767068
# 1       -0.7666850      -0.79030791       -0.8088526       -0.8202897
# 2       -0.8031237      -0.80065690       -0.7943595       -0.7832322
# 3        0.2785784      -0.02233891       -0.8344614       -1.0044925
#   153.614457831325 154.618473895582 155.622489959839 156.626506024096
# 1       -0.8228722       -0.8145883       -0.7924833       -0.7512216
# 2       -0.7670602       -0.7465418       -0.7235183       -0.7012304
# 3       -0.9947944       -0.9812626       -0.9611036       -0.9329663
#   157.630522088353 158.63453815261 159.638554216867 160.642570281125
# 1       -0.6757423      -0.3063965        0.8688481        0.9679233
# 2       -0.6807904      -0.6728119       -0.6832253       -0.7054310
# 3       -0.8974015      -0.8567861       -0.8149502       -0.7765148
#   161.646586345382 162.650602409639 163.654618473896 164.658634538153
# 1        0.7772804      -0.07183464       -1.1062019       -1.0341477
# 2       -0.7309402      -0.75082774       -0.7686511       -0.7816786
# 3       -0.7457931      -0.72540822       -0.7155786       -0.7153215
#   165.66265060241 166.666666666667 167.670682730924 168.674698795181
# 1      -0.9682607       -0.9201250       -0.8912380       -0.8785268
# 2      -0.7870605       -0.7817687       -0.7624390       -0.7245206
# 3      -0.7238374       -0.7399730       -0.7613774       -0.7843319
#   169.678714859438 170.682730923695 171.686746987952 172.690763052209
# 1       -0.8757421       -0.8765711       -0.8763897       -0.8723257
# 2       -0.6548498       -0.3204002        0.6097598        0.9159961
# 3       -0.8048796       -0.8195663       -0.8257305       -0.8215405
#   173.694779116466 174.698795180723 175.70281124498 176.706827309237
# 1       -0.8627871       -0.8471194      -0.8255329       -0.7992863
# 2        0.6867779       -0.3890717      -1.0366319       -1.0173625
# 3       -0.8059275       -0.7785542      -0.7399101       -0.6905890
#   177.710843373494 178.714859437751 179.718875502008 180.722891566265
# 1       -0.7711209       -0.7458106       -0.7301849       -0.7295152
# 2       -0.9442263       -0.8744008       -0.8208368       -0.7929042
# 3       -0.5947843       -0.4888176       -0.4608156       -0.5897696
#   181.726907630522 182.730923694779 183.734939759036 184.738955823293
# 1       -0.7412643       -0.7592950       -0.7779570       -0.7932478
# 2       -0.7922503       -0.8086421       -0.8305061       -0.8505003
# 3       -0.7499744       -0.8130170       -0.8299556       -0.8409305
#   185.74297188755 186.746987951807 187.751004016064 188.755020080321
# 1      -0.8027234       -0.8053583       -0.8015959       -0.7935596
# 2      -0.8644851       -0.8698348       -0.8643891       -0.8458421
# 3      -0.8452711       -0.8433730       -0.8365057       -0.8265279
#   189.759036144578 190.763052208835 191.767068273092 192.771084337349
# 1       -0.7852354       -0.7820492       -0.7889309       -0.8074163
# 2       -0.8111387       -0.7548184       -0.6525374       -0.1001499
# 3       -0.8155633       -0.8057013       -0.7987310       -0.7958760
#   193.775100401606 194.779116465863 195.78313253012 196.787148594378
# 1       -0.8348509       -0.8664015      -0.8970687       -0.9225360
# 2        0.9391002        0.9285660       0.6517322       -0.7358678
# 3       -0.7975586       -0.8033236      -0.8120201       -0.8221502
#   197.791164658635 198.795180722892 199.799196787149 200.803212851406
# 1       -0.9394094       -0.9452854       -0.9387656       -0.9194256
# 2       -1.0895200       -1.0154215       -0.9519020       -0.9026096
# 3       -0.8321654       -0.8405697       -0.8458446       -0.8463236
#   201.807228915663 202.81124497992 203.815261044177 204.819277108434
# 1       -0.8877457      -0.8449963       -0.7930944       -0.7343536
# 2       -0.8696398      -0.8523352       -0.8471801       -0.8494938
# 3       -0.8401411      -0.8253304       -0.8000397       -0.7627423
#   205.823293172691 206.827309236948 207.831325301205 208.835341365462
# 1       -0.6691135       -0.4838896       -0.2999128       -0.1804235
# 2       -0.8551073       -0.8607785       -0.8638455       -0.8618848
# 3       -0.7118802       -0.6216330       -0.4156647       -0.0534988
#   209.839357429719 210.843373493976 211.847389558233 212.85140562249
# 1      -0.35598898       -0.5162496       -0.2364068       0.3284619
# 2      -0.85264306       -0.8342272       -0.8054928      -0.7666557
# 3       0.02474902       -0.2568694       -0.7093632      -0.8470668
#   213.855421686747 214.859437751004 215.863453815261 216.867469879518
# 1        0.3395453        0.1645395       -0.2989640       -0.4018100
# 2       -0.7200529       -0.6620238       -0.6140577       -0.6263134
# 3       -0.8120225       -0.7573180       -0.6723234       -0.6164225
#   217.871485943775 218.875502008032 219.879518072289 220.883534136546
# 1       -0.3585309       -0.3290437       -0.5004164       -0.4362260
# 2       -0.6911566       -0.7582236       -0.7853809       -0.7957568
# 3       -0.5988228       -0.6411442       -0.6640895       -0.6739551
#   221.887550200803 222.89156626506 223.895582329317 224.899598393574
# 1       -0.3927307      -0.6306939       -0.9151246       -0.9574830
# 2       -0.7917830      -0.7707133       -0.7296389       -0.6592842
# 3       -0.6798595      -0.6872401       -0.7007792       -0.7162648
#   225.903614457831 226.907630522088 227.911646586345 228.915662650602
# 1       -0.9648791       -0.9703784       -0.9712805       -0.9661478
# 2       -0.3841880        0.3496670        0.6369398        0.3579089
# 3       -0.7369719       -0.7604956       -0.7832985       -0.8022765
#   229.919678714859 230.923694779116 231.927710843374 232.931726907631
# 1       -0.9552204       -0.9406667       -0.9264022       -0.9170391
# 2       -0.6477129       -1.0293754       -1.0263127       -0.9953023
# 3       -0.8152619       -0.8211078       -0.8195989       -0.8113355
#   233.935742971888 234.939759036145 235.943775100402 236.947791164659
# 1       -0.9158466       -0.9227888       -0.9344310       -0.9457199
# 2       -0.9687414       -0.9424557       -0.9113858       -0.8701538
# 3       -0.7976862       -0.7808822       -0.7642316       -0.7521010
#   237.951807228916 238.955823293173 239.95983935743 240.963855421687
# 1       -0.9518850       -0.9493809      -0.9360238       -0.9107472
# 2       -0.8128519       -0.7279844      -0.4718942        0.3364266
# 3       -0.7487914       -0.7560044      -0.7713512       -0.7900387
#   241.967871485944 242.971887550201 243.975903614458 244.979919678715
# 1       -0.8732292       -0.8234477       -0.7607812       -0.6682618
# 2        0.8337474        0.7125412       -0.2659209       -1.0409179
# 3       -0.8070676       -0.8182598       -0.8207339       -0.8132928
#   245.983935742972 246.987951807229 247.991967871486 248.995983935743
# 1       -0.3380864      -0.04693168       0.02820486       -0.4113500
# 2       -1.0587745      -1.01359887      -0.96467777       -0.9151047
# 3       -0.7969549      -0.77567272      -0.75689256       -0.7496483
#          250
# 1 -0.8115784
# 2 -0.8610245
# 3 -0.7570393

# %% [markdown]
# #### d) Are your labels/clusters the same? If not, why? Are your means the same?

# %% [markdown]
# They are not the same since the centroids in the first step lead to random initial centroids so the cluster numbering and assignment can shift every time the code is run. Thus, the clusters/labels might not match. The cluster means are similar to one another but they are not identical; however, the clusters would showcase similar patterns attributing to the similar cluster means.

# %% [markdown]
# ## Question 3
# #### a) Explain the process of using a for loop to assign clusters for kmeans.

# %% [markdown]
# You can loop through each point and then compute its distance to all centroids and then assign it to the closest one. This is more intuitive; however, this is can take a very long time to carry out.

# %% [markdown]
# #### b) Explain the process of vectorizing the code to assign clusters for kmeans.

# %% [markdown]
# Instead of use a for loop to assign the clusters for kmeans we can use vectorized distance computations which allows R to perfom element-wise operations across the dataset in one step making the process much faster than the initial for loop.

# %% [markdown]
# #### c) State which (for loops or vectorizing) is more efficient and why.

# %% [markdown]
# Vectorizing is more efficient because it runs much faster for large dataset since a loop is having to be evaluated for every single data point.

# %% [markdown]
# ## Question 4
# #### When does `kmeans` fail? What assumption does `kmeans` use that causes it to fail in this situation?

# %% [markdown]
# K-means fails when the clusters are not spherical in shape, not of similar size, or not well separated (i.e. are overlapping). K-means assumes that clusters are roughly spherical Gaussians of similar size and spread, and that the distances can be measured in a vector space. When these assumptions do not hold, the algorithm may misclassify points or lead to convergance.

# %% [markdown]
# ## Question 5
# #### What assumption do Guassian mixture models make?

# %% [markdown]
# Gaussian Mixture Models (GMMs) assume that data are generated from a mixture of Gaussian distributions, each with its own mean and covariance matrix. Unlike K-means, GMMs allow for each point to belong to clusters with certain probabilities.

# %% [markdown]
# ## Question 6
# #### What assumption does spectral clustering make? Why does this help us?

# %% [markdown]
# Spectral clustering assumes that data can be represented as a graph, where edges connect similar points. It uses the eigenvectors of the Laplacian graph to find clusters. This helps because it does not assume spherical or equal-sized clusters. So, it can identify arbitrarily shaped clusters and detect structure based on connectivity rather than the Euclidean distance alone.

# %% [markdown]
# ## Question 7
# #### Define the gap statistic method. What do we use it for?

# %% [markdown]
# The gap statistic compares the total within-cluster variation for different values of k (number of clusters) to the expected under a null reference distribution. It is used to determine the optimal number of clusters, which is the value of k where the gap statistic is maximized. This indicates that the clustering is significantly better than random uniform clustering.
